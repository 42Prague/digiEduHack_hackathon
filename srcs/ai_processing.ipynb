# %%
import pandas as pd
import numpy as np
import librosa
import glob

# %%
# Creating a session
from pyspark.sql import SparkSession

def create_session():
    spark = SparkSession.builder \
        .appName("processing_core") \
        .getOrCreate()
    # Disables warnings
    spark.sparkContext.setLogLevel("ERROR")

# %%
# Loading audio
# def load_audio():
    # """
    # Loads audio file for future pipelines. Available for .wav, .mp3, .flac, .ogg. .m4a formats"
    # """
folder = "/home/sofiemeyer/Projects/hackathon/data_samples_eduzmena/Data samples"

# List of common audio extensions
audio_exts = ["wav", "mp3", "flac", "ogg", "m4a"]

# Collect all audio files
audio_files = []
for ext in audio_exts:
    audio_files.extend(glob.glob(os.path.join(folder, f"*.{ext}")))
    audio_files.extend(glob.glob(os.path.join(folder, f"*.{ext.upper()}")))  # handle uppercase

print(audio_files)
# Out:
# ['/home/sofiemeyer/Projects/hackathon/data_samples_eduzmena/Data samples/Zaznam_FG_PedagogLidr_SKUPINA-B-android.mp3', '/home/sofiemeyer/Projects/hackathon/data_samples_eduzmena/Data samples/Zaznam_FG_PedagogLidr_SKUPINA-A.MP3', '/home/sofiemeyer/Projects/hackathon/data_samples_eduzmena/Data samples/Zaznam_FG_PedagogLidr_mentori.m4a', '/home/sofiemeyer/Projects/hackathon/data_samples_eduzmena/Data samples/2024_9_FG-PL-ucastnici_ZAZNAM-IPHONE.m4a']

# %%
# Out:
# []
